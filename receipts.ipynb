# %%
import pandas as pd
import numpy as np

# %%
receipts = pd.read_json('./receipts.json', lines=True)

# %%
receipts.describe(include='all')
# Out:
#                                          _id  bonusPointsEarned  \
# count                                   1119         544.000000
# unique                                  1119                NaN
# top     {'$oid': '5ff1e1eb0a720f0523000575'}                NaN
# freq                                       1                NaN
# mean                                     NaN         238.893382
# std                                      NaN         299.091731
# min                                      NaN           5.000000
# 25%                                      NaN           5.000000
# 50%                                      NaN          45.000000
# 75%                                      NaN         500.000000
# max                                      NaN         750.000000
#
#            bonusPointsEarnedReason                createDate  \
# count                          544                      1119
# unique                           9                      1107
# ...

# %% [markdown]
# From this, I would want to look into the columns with null values: `finishedDate`, `pointsAwardedDate`, `pointsEarned`, `purchaseDate`, `purchasedItemCount`, `rewardsReceiptItemList` and `totalSpent`. This is especially because of the discrepany between the count of non-null values in each column. Where are the misalignments happening?
