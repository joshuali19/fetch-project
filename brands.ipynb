# %%
import pandas as pd
import numpy as np

# %%
brands = pd.read_json('./brands.json', lines=True)

# %%
brands.describe(include='all')
# brands.describe()
# Out:
#                                          _id       barcode category  \
# count                                   1167  1.167000e+03     1012
# unique                                  1167           NaN       23
# top     {'$oid': '601ac115be37ce2ead437551'}           NaN   Baking
# freq                                       1           NaN      369
# mean                                     NaN  5.111115e+11      NaN
# std                                      NaN  2.874497e+05      NaN
# min                                      NaN  5.111110e+11      NaN
# 25%                                      NaN  5.111112e+11      NaN
# 50%                                      NaN  5.111114e+11      NaN
# 75%                                      NaN  5.111117e+11      NaN
# max                                      NaN  5.111119e+11      NaN
#
#        categoryCode                                                cpg  \
# count           517                                               1167
# ...

# %% [markdown]
# `id` is all unique, which is good.

# %%
pd.crosstab(brands.category, brands.categoryCode, dropna=False)
# Out:
# categoryCode                 BABY  BAKING  BEER_WINE_SPIRITS  BEVERAGES  \
# category
# Baby                            7       0                  0          0
# Baking                          0     359                  0          0
# Beer Wine Spirits               0       0                 31          0
# Beverages                       0       0                  0          1
# Bread & Bakery                  0       0                  0          0
# Candy & Sweets                  0       0                  0          0
# Cleaning & Home Improvement     0       0                  0          0
# Dairy & Refrigerated            0       0                  0          0
# Frozen                          0       0                  0          0
# Grocery                         0       0                  0          0
# Health & Wellness               0       0                  0          0
# Magazines                       0       0                  0          0
# ...

# %% [markdown]
# There seems to be a misalignment with the `category` column and the `categoryCode` column. While the alignment for 14 categories is correct, as indicated by the diagonal matrix above, there are still 9 categories in the `category` column that are unaccounted for.

# %%
brands.topBrand.isna().sum()
# Out:
# 612

# %% [markdown]
# There seems to be an issue with the `topBrand` column. There are 612 NA values in a True/False column. We would need to decide if imputation is a viable option. Otherwise, we need to sort that out in the data processing step.

# %%
brands.groupby(['brandCode']).count()
# Out:
#                     _id  barcode  category  categoryCode  cpg  name  topBrand
# brandCode
#                      35       35        35             0   35    35        32
#  MILANO               1        1         1             0    1     1         1
#  SOBE                 1        1         1             0    1     1         0
#  TAZO BOTTLED TEAS    1        1         1             0    1     1         0
# 09090909090           1        1         1             0    1     1         1
# ...                 ...      ...       ...           ...  ...   ...       ...
# YOPLAIT GO-GURT       1        1         1             0    1     1         0
# YQ YOPLAIT            1        1         1             0    1     1         0
# YUBAN                 1        1         1             0    1     1         1
# ZIMA                  1        1         1             0    1     1         0
# ZUMBIDA               1        1         1             0    1     1         0
#
# [897 rows x 7 columns]

# %%
brands[brands.brandCode == ''].head(10)
# Out:
#                                       _id       barcode             category  \
# 124  {'$oid': '57ebc11fe4b0ac389136a33a'}  511111802075               Baking
# 153  {'$oid': '58861c7d4e8d0d20bc42c4d6'}  511111601449               Snacks
# 163  {'$oid': '57ebc2ace4b0ac389136a346'}  511111801962                 Deli
# 188  {'$oid': '58b59989e4b0857c2ddb7255'}  511111400998    Beer Wine Spirits
# 234  {'$oid': '58b5988ce4b0857c2ddb7252'}  511111301028    Beer Wine Spirits
# 236  {'$oid': '57ebc125e4b0ac389136a33b'}  511111302063              Grocery
# 278  {'$oid': '585a967fe4b03e62d1ce0e80'}  511111801689               Snacks
# 288  {'$oid': '585a96d2e4b03e62d1ce0e89'}  511111001607            Beverages
# 297  {'$oid': '580e015be4b0f32b2de21385'}  511111501824  Condiments & Sauces
# 302  {'$oid': '588b9ff4e4b02187f85cdadb'}  511111901099  Condiments & Sauces
#
#     categoryCode                                                cpg  \
# ...

# %% [markdown]
# There also seems to be an issue with the `brandCode` column. There is a blank value that is being registered for 35 products, some of which do have associated brand codes.
